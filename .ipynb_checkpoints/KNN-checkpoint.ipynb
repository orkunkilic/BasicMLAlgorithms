# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
x = [i for i in range(10)]
y = [2*i for i in range(10)]

# %%
plt.plot(x, y)
plt.xlabel('X')
plt.ylabel('X**2')
# Out:
# Text(0, 0.5, 'Y')
